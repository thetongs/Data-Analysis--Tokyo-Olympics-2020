# %%
## Load Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## Load dataset
# Discipline = Sport, NOC - National Olympic Committee
# Their role is to ensure the representation of their respective countries at the Olympic Games by sending competitors and 
# officials as well as to promote the fundamental principles and values of Olympism in their countries, 
# in particular in the fields of sport and education.
#
dataset = pd.read_excel("Dataset\Teams.xlsx", engine='openpyxl')
dataset.head()
# Out:
#       Name      Discipline                         NOC  Event
# 0  Belgium  3x3 Basketball                     Belgium    Men
# 1    China  3x3 Basketball  People's Republic of China    Men
# 2    China  3x3 Basketball  People's Republic of China  Women
# 3   France  3x3 Basketball                      France  Women
# 4    Italy  3x3 Basketball                       Italy  Women

# %%
## Basic Information Of Dataset
#
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 743 entries, 0 to 742
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        743 non-null    object
#  1   Discipline  743 non-null    object
#  2   NOC         743 non-null    object
#  3   Event       743 non-null    object
# dtypes: object(4)
# memory usage: 23.3+ KB

# %%
## Statistics Information Of Dataset
#
dataset.describe()
# Out:
#          Name Discipline    NOC Event
# count     743        743    743   743
# unique    146         20     84    36
# top     Japan   Swimming  Japan   Men
# freq       45        113     48   120

# %%
## Count unique values of all features in dataset
#
columns = dataset.describe().columns
unique_count = dataset.describe()[dataset.describe().index == 'unique'].values.flatten().tolist()

plt.bar(x = columns, height = unique_count)
plt.title("Visual Representation Of Unique Value In Each Features")
plt.xlabel("Features")
plt.ylabel("Unique value of each feature")
plt.show()
plt.close()

# %%
## Teams Participated Count With Unique Sport
#
sns.countplot(data = dataset, x = 'Discipline')
plt.title("Count of unique sports/discipline")
plt.xlabel('Sports')
plt.ylabel('Counts')
plt.xticks(rotation='vertical')
plt.show()
plt.close()

# %%
## Teams Participated Counts With Country
#
sns.countplot(data = dataset, x = 'Name')
plt.rc('figure', figsize=(30, 8))
plt.title("Count of Teams With Nation")
plt.xlabel('Names')
plt.ylabel('Counts')
plt.xticks(rotation='vertical')
plt.show()
plt.close()

# %%
## Load Second Dataset
#
dataset1 = pd.read_excel("Dataset\Athletes.xlsx", engine = 'openpyxl')
dataset1.head()
# Out:
#                 Name     NOC           Discipline
# 0    AALERUD Katrine  Norway         Cycling Road
# 1        ABAD Nestor   Spain  Artistic Gymnastics
# 2  ABAGNALE Giovanni   Italy               Rowing
# 3     ABALDE Alberto   Spain           Basketball
# 4      ABALDE Tamara   Spain           Basketball

# %%
## Athlete Count With Each Sport
#
sns.countplot(data = dataset1, x = 'Discipline')
plt.rc('figure', figsize=(30, 8))
plt.title("Count of Sport With Atheletes")
plt.xlabel('Sports')
plt.ylabel('Counts')
plt.xticks(rotation='vertical')
plt.show()
plt.close()

# %%
## Load Third Dataset
#
import warnings
warnings.filterwarnings('ignore')

dataset2 = pd.read_excel("Dataset\Coaches.xlsx", engine = 'openpyxl')
dataset2.head()
# Out:
#               Name            NOC  Discipline Event
# 0  ABDELMAGID Wael          Egypt    Football   NaN
# 1        ABE Junya          Japan  Volleyball   NaN
# 2    ABE Katsuhiko          Japan  Basketball   NaN
# 3     ADAMA Cherif  Côte d'Ivoire    Football   NaN
# 4       AGEBA Yuya          Japan  Volleyball   NaN

# %%
## Coaches Counts with sports
#
sns.countplot(data = dataset2, x = 'Discipline')
plt.rc('figure', figsize=(30, 8))
plt.title("Count of Coaches with each Sport")
plt.xlabel('Sports')
plt.ylabel('Counts')
plt.xticks(rotation='vertical')
plt.show()
plt.close()

# %%
## Load Fourth Dataset
#
import warnings
warnings.filterwarnings('ignore')

dataset3 = pd.read_excel("Dataset\EntriesGender.xlsx", engine = 'openpyxl')
dataset3.head()
# Out:
#             Discipline  Female  Male  Total
# 0       3x3 Basketball      32    32     64
# 1              Archery      64    64    128
# 2  Artistic Gymnastics      98    98    196
# 3    Artistic Swimming     105     0    105
# 4            Athletics     969  1072   2041

# %%
## Female and Male count In Each Sports
#
dataset3.plot(x="Discipline", y=["Female", "Male"], kind="bar")
plt.title("Female/Male Ration In Each Sport")
plt.xlabel('Sports')
plt.ylabel('Counts')
plt.xticks(rotation='vertical')
plt.show()
plt.close()

# %%
## Load Fifth Dataset
#
import warnings
warnings.filterwarnings('ignore')

dataset4 = pd.read_excel("Dataset\Medals.xlsx", engine = 'openpyxl')
dataset4.head()
# Out:
#    Rank                    Team/NOC  Gold  Silver  Bronze  Total  \
# 0     1    United States of America     7       3       4     14
# 1     2                       Japan     7       1       3     11
# 2     3  People's Republic of China     6       3       6     15
# 3     4               Great Britain     3       2       1      6
# 4     5           Republic of Korea     3       0       4      7
#
#    Rank by Total
# 0              2
# 1              3
# 2              1
# 3              7
# 4              6

# %%
## Medals Summary with each Country
#
s1 = sns.barplot(x = 'Team/NOC', y = 'Gold', data = dataset4, color = 'red')
s2 = sns.barplot(x = 'Team/NOC', y = 'Silver', data = dataset4, color = 'grey')
s2 = sns.barplot(x = 'Team/NOC', y = 'Bronze', data = dataset4, color = 'orange')
plt.title("Count of Different Medals with Country")
plt.xlabel('Country')
plt.ylabel('Counts')
plt.xticks(rotation='vertical')
plt.show()
plt.close()

# %%
## End
#
